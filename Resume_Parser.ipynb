# %% [markdown]
# <a href="https://colab.research.google.com/github/Yarra-Hemanth/Mini-Project/blob/main/Resume_Parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# !wget https://huggingface.co/datasets/Mehyaar/Annotated_NER_PDF_Resumes/resolve/main/ResumesJsonAnnotated.zip
# Out:
# --2025-03-10 09:50:16--  https://huggingface.co/datasets/Mehyaar/Annotated_NER_PDF_Resumes/resolve/main/ResumesJsonAnnotated.zip
# Resolving huggingface.co (huggingface.co)... 54.230.71.56, 54.230.71.103, 54.230.71.28, ...
# Connecting to huggingface.co (huggingface.co)|54.230.71.56|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip ResumesJsonAnnotated.zip -d resumes_data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1024)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1025)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1026)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1027)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1028)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1029)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (103)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1030)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1031)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1032)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1033)_annotated.json
#   inflating: resumes_data/ResumesJsonAnnotated/cv (1034)_annotated.json
# ...

# %%
import json
import pandas as pd

# Load JSON file (adjust filename if needed)
with open("content/resumes_data/ResumesJsonAnnotated/cv (502)_annotated.json ", "r") as file:
    data = json.load(file)

# Convert to DataFrame
df = pd.DataFrame(data)
print(df.head())  # Preview the first few records
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-1d6b64c6c979> in <cell line: 0>()
#       3
#       4 # Load JSON file (adjust filename if needed)
# ----> 5 with open("content/resumes_data/ResumesJsonAnnotated/cv(502)_annotated.json ", "r") as file:
#       6     data = json.load(file)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'content/resumes_data/ResumesJsonAnnotated/cv(502)_annotated.json '

# %%
import os

folder_path = "resumes_data/ResumesJsonAnnotated"

# List files in the folder
print(os.listdir(folder_path))
# Out:
# ['cv (1465)_annotated.json', 'cv (3632)_annotated.json', 'cv (1781)_annotated.json', 'cv (1650)_annotated.json', 'cv (4566)_annotated.json', 'cv (522)_annotated.json', 'cv (1898)_annotated.json', 'cv (1338)_annotated.json', 'cv (674)_annotated.json', 'cv (4000)_annotated.json', 'cv (3751)_annotated.json', 'cv (1499)_annotated.json', 'cv (975)_annotated.json', 'cv (3773)_annotated.json', 'cv (3382)_annotated.json', 'cv (4383)_annotated.json', 'cv (2661)_annotated.json', 'cv (1926)_annotated.json', 'cv (519)_annotated.json', 'cv (4604)_annotated.json', 'cv (2216)_annotated.json', 'cv (4056)_annotated.json', 'cv (468)_annotated.json', 'cv (302)_annotated.json', 'cv (4838)_annotated.json', 'cv (1994)_annotated.json', 'cv (233)_annotated.json', 'cv (4664)_annotated.json', 'cv (1368)_annotated.json', 'cv (4339)_annotated.json', 'cv (4340)_annotated.json', 'cv (3636)_annotated.json', 'cv (3038)_annotated.json', 'cv (2157)_annotated.json', 'cv (2883)_annotated.json', 'cv (4810)_annotated.jso
# ...

# %%
for filename in os.listdir(folder_path):
    new_filename = filename.replace(" ", "_").replace("(", "").replace(")", "")  # Remove spaces and parentheses
    os.rename(os.path.join(folder_path, filename), os.path.join(folder_path, new_filename))

print("Files renamed successfully!")
# Out:
# Files renamed successfully!

# %%
print(os.listdir(folder_path))
# Out:
# ['cv_2061_annotated.json', 'cv_2878_annotated.json', 'cv_2899_annotated.json', 'cv_1769_annotated.json', 'cv_2158_annotated.json', 'cv_4517_annotated.json', 'cv_1289_annotated.json', 'cv_875_annotated.json', 'cv_747_annotated.json', 'cv_3298_annotated.json', 'cv_1002_annotated.json', 'cv_1203_annotated.json', 'cv_4000_annotated.json', 'cv_3302_annotated.json', 'cv_4074_annotated.json', 'cv_4026_annotated.json', 'cv_1661_annotated.json', 'cv_1048_annotated.json', 'cv_2162_annotated.json', 'cv_2334_annotated.json', 'cv_2575_annotated.json', 'cv_2882_annotated.json', 'cv_3331_annotated.json', 'cv_3196_annotated.json', 'cv_3568_annotated.json', 'cv_565_annotated.json', 'cv_2621_annotated.json', 'cv_3465_annotated.json', 'cv_42_annotated.json', 'cv_2471_annotated.json', 'cv_615_annotated.json', 'cv_1825_annotated.json', 'cv_2574_annotated.json', 'cv_3763_annotated.json', 'cv_4741_annotated.json', 'cv_4456_annotated.json', 'cv_1998_annotated.json', 'cv_1656_annotated.json', 'cv_3309_annota
# ...

# %%
with open("/content/resumes_data/ResumesJsonAnnotated/cv_1000_annotated.json", "r") as file:
    data = json.load(file)

# Convert to DataFrame
df = pd.DataFrame(data)
print(df.head())  # Preview the first few records
# Out:
#                                                 text  \
# 0  ARUN KUMAR U.C.  \n \nMob :+91 9745004628     ...
# 1  ARUN KUMAR U.C.  \n \nMob :+91 9745004628     ...
# 2  ARUN KUMAR U.C.  \n \nMob :+91 9745004628     ...
# 3  ARUN KUMAR U.C.  \n \nMob :+91 9745004628     ...
# 4  ARUN KUMAR U.C.  \n \nMob :+91 9745004628     ...
#
#                           annotations
# 0       [415, 425, SKILL: WINDOWS XP]
# 1  [709, 724, SKILL: Problem solving]
# 2      [1349, 1358, SKILL: Knowledge]
# 3             [531, 535, SKILL: Arts]
# 4            [1042, 1045, SKILL: LTD]

# %%
import os
import json
import pandas as pd

# Path to the folder containing JSON resumes
folder_path = "/content/resumes_data/ResumesJsonAnnotated"

# List to store extracted resume data
resume_data = []

# Loop through each JSON file in the directory
for file_name in os.listdir(folder_path):
    if file_name.endswith(".json"):  # Process only JSON files
        file_path = os.path.join(folder_path, file_name)

        try:
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)  # Load JSON file
                extracted_text = data.get("text", "")  # Extract resume text
                annotations = data.get("annotations", [])  # Extract annotations

                # Append extracted data to list
                resume_data.append({"file_name": file_name, "text": extracted_text, "annotations": annotations})

        except Exception as e:
            print(f"Error reading {file_name}: {e}")

# Convert extracted data into a DataFrame
df = pd.DataFrame(resume_data)
print("Total Resumes Processed:", len(df))
df.head()
# Out:
# Total Resumes Processed: 5029
#                 file_name                                               text  \
# 0  cv_2061_annotated.json  CURRICULUM VITAE\nMOHAMMAD ASIF\nWHATSAPP NO :...
# 1  cv_2878_annotated.json                            CURRI  CUL  UM VI  T...
# 2  cv_2899_annotated.json                                 RESUME\nMOHAMME...
# 3  cv_1769_annotated.json  RESUME\nKURALARASAN.M\n2/163,WEST STREET,\nSOU...
# 4  cv_2158_annotated.json   CURRICULUM VITEA  \nEducation / \ntraining:\n...
#
#                                          annotations
# 0  [[1652, 1659, SKILL: Ability], [1529, 1538, SK...
# 1  [[3550, 3557, SKILL: Reports], [468, 476, SKIL...
# 2  [[897, 904, SKILL: Ability], [160, 165, SKILL:...
# 3  [[496, 503, SKILL: Ability], [134, 139, SKILL:...
# 4  [[1565, 1607, SKILL: Excellent verbal and writ...

# %%
df['text'][0]
# Out:
# 'CURRICULUM VITAE\nMOHAMMAD ASIF\nWHATSAPP NO : +97155 5926698 \nMobile India: +91 8860139778 ,+919871785801\nEmail ID-Asif_khan_uae92@yahoo.com\nSkype ID-Asifkhan907\nDubai, U.A.E POST APPLIED FOR : AUTOMOBILE PETROL MECHANIC\ntechnician OBJECTIVE:\nSeeking a suitable position with substantial responsibilities where my varied \nexperience would be fully utilized and where I could make a significant contribution \nto my employer which will gain me carrier opportunities. \nPERSONAL INFORMATION: \nFather Name :Mohamed Abid\nDate of Birth :10/02/1985\nGender :Male\nNationality :Indian\nMarital Status :Single\nReligion :Muslim\nLanguages Known :English, Urdu & Hindi . \nPASSPORT DETAILS :\nPassport No :        P 5159433\nDate of Issue :5/01/2017\nDate of Expiry :4/01/2027\nPlace of issue :Bareilly.\nSUMMARY OF QUALIFICATION:\n\uf0d8Metric pass\nWork Experience : Malty brand model Audi, vw , bmw ,skoda,hyundai,land \nrover\n HONDA,LEXUS,TOYOTA ,FORD,GMC,SEAT ALL VEHICLE EXPERIENCE. \nCurr
# ...

# %%
df.loc[0]
# Out:
# file_name                                 cv_2061_annotated.json
# text           CURRICULUM VITAE\nMOHAMMAD ASIF\nWHATSAPP NO :...
# annotations    [[1652, 1659, SKILL: Ability], [1529, 1538, SK...
# Name: 0, dtype: object
